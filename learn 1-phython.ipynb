# %% [markdown]
# <a href="https://colab.research.google.com/github/lanita21/Pembelajaran-C-Fundamental-/blob/main/learn%201-phython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materi pertama pembelajaran tentang phython

# %%
a=2
b=3
c=a+b
print (c)
# Out:
# 5
